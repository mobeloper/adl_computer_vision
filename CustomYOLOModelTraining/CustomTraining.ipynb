# %%
# !unzip vott-csv-export.zip
# Out:
# Archive:  vott-csv-export.zip
#    creating: vott-csv-export/
#   inflating: vott-csv-export/cat.14.jpg
#   inflating: vott-csv-export/cat.16.jpg
#   inflating: vott-csv-export/cat.2.jpg
#   inflating: vott-csv-export/cat.3.jpg
#   inflating: vott-csv-export/cat.4.jpg
#   inflating: vott-csv-export/cat.41.jpg
#   inflating: vott-csv-export/cat.42.jpg
#   inflating: vott-csv-export/cat.50.jpg
#   inflating: vott-csv-export/cat.54.jpg
#   inflating: vott-csv-export/cat.8.jpg
#   inflating: vott-csv-export/CatDogYolo-export.csv
#   inflating: vott-csv-export/dog.2.jpg
#   inflating: vott-csv-export/dog.4.jpg
#   inflating: vott-csv-export/dog.45.jpg
#   inflating: vott-csv-export/dog.5.jpg
#   inflating: vott-csv-export/dog.51.jpg
#   inflating: vott-csv-export/dog.57.jpg
#   inflating: vott-csv-export/dog.69.jpg
#   inflating: vott-csv-export/dog.8.jpg
#   inflating: vott-csv-export/dog.9.jpg
#   inflating: vott-csv-export/dog.99.jpg

# %%
import os
import pandas as pd
import cv2

# Define paths
csv_file = 'vott-csv-export/CatDogYolo-export.csv'
images_dir = 'vott-csv-export'
output_dir = 'outputCompatible'

# Create output directories if they do not exist
os.makedirs(output_dir, exist_ok=True)
os.makedirs(os.path.join(output_dir, 'images'), exist_ok=True)
os.makedirs(os.path.join(output_dir, 'labels'), exist_ok=True)

# Read the CSV file
df = pd.read_csv(csv_file)

# Define a mapping for class names to class IDs
class_mapping = {'cat': 0, 'dog': 1}  # Update this with your classes

# Process each row in the CSV
for index, row in df.iterrows():
    image_name = row['image']
    image_path = os.path.join(images_dir, image_name)
    output_image_path = os.path.join(output_dir, 'images', image_name)
    label_path = os.path.join(output_dir, 'labels', os.path.splitext(image_name)[0] + '.txt')

    # Copy the image to the output directory
    os.system(f'cp {image_path} {output_image_path}')

    # Get bounding box information
    class_name = row['label']
    class_id = class_mapping[class_name]
    xmin = row['xmin']
    ymin = row['ymin']
    xmax = row['xmax']
    ymax = row['ymax']

    # Calculate normalized coordinates
    img = cv2.imread(image_path)
    img_h, img_w, _ = img.shape
    x_center = (xmin + xmax) / 2 / img_w
    y_center = (ymin + ymax) / 2 / img_h
    w = (xmax - xmin) / img_w
    h = (ymax - ymin) / img_h

    # Write to the label file
    with open(label_path, 'w') as f:
        f.write(f'{class_id} {x_center} {y_center} {w} {h}\n')

print('Dataset conversion completed!')
# Out:
# Dataset conversion completed!

# %%
# %%writefile custom_dataset.yaml
#
# train: /content/outputCompatible/images
# val: /content/outputCompatible/images
#
# # number of classes
# nc: 2  # Update this with the number of your classes
#
# # class names
# names: ['cat', 'dog']  # Update this with your class names
# Out:
# Writing custom_dataset.yaml

# %% [markdown]
# # Install Yolov5 Framework

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17395, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17395 (delta 35), reused 32 (delta 13), pack-reused 17318 (from 5)
# Receiving objects: 100% (17395/17395), 16.29 MiB | 17.00 MiB/s, done.
# Resolving deltas: 100% (11924/11924), done.

# %%
# !cd yolov5

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 58.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 1 --data custom_dataset.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-28 02:24:42.622907: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743128682.642827    5091 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743128682.648913    5091 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# ...

# %%
import torch
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the trained YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/best.pt')  # Update the path to your weights file
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2025-3-28 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
