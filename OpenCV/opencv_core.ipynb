# %% [markdown]
# # OpenCV

# %%
# !pip install opencv-python

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.9.0'

# %%
# Get an available camera index
cam_index=-1
for i in range(5):  # Check up to 5 cameras
    cap = cv2.VideoCapture(i)
    if cap.isOpened():
        print(f"Camera {i} is available.")
        cap.release()
        cam_index=i
        break
    else:
        print(f"Camera {i} is not available.")
# Out:
# Camera 0 is available.

# %% [markdown]
# ## Camera Feed

# %%
import cv2

if cam_index<0:
    print(f"NO CAMERA DETECTED. Make sure you connected your camera properly")

#Enable camera
camera = cv2.VideoCapture(cam_index)

# Get the realtime feeds from camera
while(True):
    _,frame = camera.read() #metrics,frame = camera.read()
    
    #Display frame on a window
    cv2.imshow("Device Camera View", frame)
    
    #Terminate Condition ----- Press Q to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

#Cleanup and free the memory resources
camera.release()
cv2.destroyAllWindows()
    

for i in range(2):
    cv2.waitKey(1)
# Out:
# 2025-03-20 22:21:19.505 python[46919:1631913] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-20 22:21:19.505 python[46919:1631913] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# # Load Image from disk

# %%
import cv2

#Load image
inputImage = cv2.imread('/Users/oysterable/delete/adl_computer_vision/OpenCV/imgdogeg.jpg')

#View image
cv2.imshow("Image View", inputImage)

#Terminate with any key
cv2.waitKey()


for i in range(2):
    cv2.waitKey()

#Cleanup and free the memory resources
cv2.destroyAllWindows()

# %% [markdown]
# # Draw Rectangle

# %%
import cv2

import numpy as np

#black image example
imgExample = np.zeros((512,512,3), np.uint8)

#             
cv2.rectangle(imgExample, (100,100), (300,450), (255,0,255), 2)

cv2.imshow("Black Image", imgExample)

cv2.waitKey()

cv2.destroyAllWindows()

for i in range(2):
    cv2.waitKey()

# %% [markdown]
# # Face Detection in Video Feed using OpenCV
#
# ### Viola Jones Algorithm
# Reference:
# https://github.com/opencv/opencv/tree/4.x/data/haarcascades

# %%
import cv2


#Enable camera
camera = cv2.VideoCapture(0)

faceModel = cv2.CascadeClassifier("./haarcascade_frontalface_default.xml")

def detectFaceFromCamera(frame):
    imgCopy = frame.copy()
    faceRectCords, accuracies = faceModel.detectMultiScale2(imgCopy, minNeighbors=10)
    
    #Here cord will be x,y,w,h
    #x,y ---> top left coords of rectange
    #w -----> width
    #h -----> height

    #Get All Bounding Boxes
    for (rect,accuracy) in zip(faceRectCords, accuracies):
        (x,y,w,h)=rect
        cv2.rectangle(imgCopy, (x,y), (x+w, y+h), (0,0,255) , 2)
        cv2.putText(imgCopy, f"{accuracy}",(x-5,y-5), cv2.FONT_HERSHEY_COMPLEX, 1.5,  (255,0,0), 2)
        print(f"Detected face with confidence accuracy as {accuracy}")

    return imgCopy

# Get the realtime feeds from camera
while(True):
    _,frame = camera.read() #metrics,frame = camera.read()
    
    #Get all Bounding Boxes Detected
    newFrame = detectFaceFromCamera(frame)
    
    #Display frame on a window
    cv2.imshow("Device Camera View", newFrame)
    
    #Terminate Condition ----- Press Q to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

#Cleanup and free the memory resources
camera.release()
cv2.destroyAllWindows()
    

for i in range(2):
    cv2.waitKey(1)
# Out:
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 13
# Detected face with confidence accuracy as 26
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 88
# Detected face with confidence accuracy as 85
# Detected face with confidence accuracy as 77
# Detected face with confidence accuracy as 75
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 77
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 73
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 22
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 70
# Detected face with confidence accuracy as 75
# Detected face with confidence accuracy as 70
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 75
# Detected face with confidence accuracy as 66
# Detected face with confidence accuracy as 58
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 42
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 14
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 59
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 31
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 28
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 30
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 59
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 28
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 56
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 66
# Detected face with confidence accuracy as 90
# Detected face with confidence accuracy as 82
# Detected face with confidence accuracy as 89
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 91
# Detected face with confidence accuracy as 66
# Detected face with confidence accuracy as 87
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 91
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 92
# Detected face with confidence accuracy as 65
# Detected face with confidence accuracy as 93
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 93
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 90
# Detected face with confidence accuracy as 74
# Detected face with confidence accuracy as 87
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 82
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 87
# Detected face with confidence accuracy as 74
# Detected face with confidence accuracy as 83
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 86
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 80
# Detected face with confidence accuracy as 94
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 86
# Detected face with confidence accuracy as 86
# Detected face with confidence accuracy as 93
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 79
# Detected face with confidence accuracy as 74
# Detected face with confidence accuracy as 80
# Detected face with confidence accuracy as 61
# Detected face with confidence accuracy as 82
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 65
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 61
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 55
# Detected face with confidence accuracy as 65
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 59
# Detected face with confidence accuracy as 30
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 58
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 53
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 28
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 56
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 66
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 93
# Detected face with confidence accuracy as 42
# Detected face with confidence accuracy as 102
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 71
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 53
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 79
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 79
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 80
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 97
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 88
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 56
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 73
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 42
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 55
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 29
# Detected face with confidence accuracy as 21
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 21
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 90
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 106
# Detected face with confidence accuracy as 75
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 74
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 79
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 74
# Detected face with confidence accuracy as 26
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 65
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 61
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 53
# Detected face with confidence accuracy as 56
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 55
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 53
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 42
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 42
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 34
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 58
# Detected face with confidence accuracy as 15
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 43
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 22
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 14
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 22
# Detected face with confidence accuracy as 30
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 23
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 31
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 26
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 40
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 91
# Detected face with confidence accuracy as 97
# Detected face with confidence accuracy as 116
# Detected face with confidence accuracy as 112
# Detected face with confidence accuracy as 117
# Detected face with confidence accuracy as 125
# Detected face with confidence accuracy as 130
# Detected face with confidence accuracy as 104
# Detected face with confidence accuracy as 104
# Detected face with confidence accuracy as 102
# Detected face with confidence accuracy as 116
# Detected face with confidence accuracy as 108
# Detected face with confidence accuracy as 103
# Detected face with confidence accuracy as 99
# Detected face with confidence accuracy as 107
# Detected face with confidence accuracy as 102
# Detected face with confidence accuracy as 81
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 38
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 45
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 22
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 30
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 47
# Detected face with confidence accuracy as 25
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 26
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 27
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 57
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 94
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 86
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 79
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 69
# Detected face with confidence accuracy as 90
# Detected face with confidence accuracy as 70
# Detected face with confidence accuracy as 89
# Detected face with confidence accuracy as 70
# Detected face with confidence accuracy as 83
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 86
# Detected face with confidence accuracy as 72
# Detected face with confidence accuracy as 81
# Detected face with confidence accuracy as 83
# Detected face with confidence accuracy as 92
# Detected face with confidence accuracy as 99
# Detected face with confidence accuracy as 80
# Detected face with confidence accuracy as 98
# Detected face with confidence accuracy as 76
# Detected face with confidence accuracy as 105
# Detected face with confidence accuracy as 96
# Detected face with confidence accuracy as 106
# Detected face with confidence accuracy as 100
# Detected face with confidence accuracy as 104
# Detected face with confidence accuracy as 90
# Detected face with confidence accuracy as 95
# Detected face with confidence accuracy as 100
# Detected face with confidence accuracy as 80
# Detected face with confidence accuracy as 113
# Detected face with confidence accuracy as 78
# Detected face with confidence accuracy as 119
# Detected face with confidence accuracy as 68
# Detected face with confidence accuracy as 119
# Detected face with confidence accuracy as 64
# Detected face with confidence accuracy as 95
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 91
# Detected face with confidence accuracy as 65
# Detected face with confidence accuracy as 96
# Detected face with confidence accuracy as 81
# Detected face with confidence accuracy as 89
# Detected face with confidence accuracy as 84
# Detected face with confidence accuracy as 92
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 96
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 77
# Detected face with confidence accuracy as 22
# Detected face with confidence accuracy as 62
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 60
# Detected face with confidence accuracy as 54
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 26
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 46
# Detected face with confidence accuracy as 44
# Detected face with confidence accuracy as 52
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 37
# Detected face with confidence accuracy as 41
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 36
# Detected face with confidence accuracy as 28
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 13
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 14
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 17
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 11
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 35
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 14
# Detected face with confidence accuracy as 99
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 116
# Detected face with confidence accuracy as 67
# Detected face with confidence accuracy as 126
# Detected face with confidence accuracy as 63
# Detected face with confidence accuracy as 119
# Detected face with confidence accuracy as 48
# Detected face with confidence accuracy as 108
# Detected face with confidence accuracy as 49
# Detected face with confidence accuracy as 112
# Detected face with confidence accuracy as 50
# Detected face with confidence accuracy as 106
# Detected face with confidence accuracy as 113
# Detected face with confidence accuracy as 109
# Detected face with confidence accuracy as 108
# Detected face with confidence accuracy as 108
# Detected face with confidence accuracy as 89
# Detected face with confidence accuracy as 82
# Detected face with confidence accuracy as 51
# Detected face with confidence accuracy as 39
# Detected face with confidence accuracy as 32
# Detected face with confidence accuracy as 31
# Detected face with confidence accuracy as 12
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 20
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 13
# Detected face with confidence accuracy as 14
# Detected face with confidence accuracy as 18
# Detected face with confidence accuracy as 16
# Detected face with confidence accuracy as 19
# Detected face with confidence accuracy as 24
# Detected face with confidence accuracy as 28
# Detected face with confidence accuracy as 31
# Detected face with confidence accuracy as 33
# Detected face with confidence accuracy as 53
# Detected face with confidence accuracy as 55
